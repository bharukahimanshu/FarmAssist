# %%
import pandas as pd

# %%
#read rainfall.csv from data raw
rainfall= pd.read_csv('../Dataset Raw/Rainfall.csv')
rainfall
# Out:
#             DIST   VAR    Year   Jan   Feb    Mar    Apr    May    Jun    Jul  \
# 0       Adilabad  RAIN  1901.0  14.8  74.1   19.3   64.2   11.7  159.1  337.9
# 1       Adilabad  RAIN  1902.0   0.0   0.0    0.2    7.6   13.3   28.9  256.7
# 2       Adilabad  RAIN  1903.0   5.0   7.7    0.0    2.5   15.4  103.5  516.4
# 3       Adilabad  RAIN  1904.0   6.8   0.7   10.3    0.7   31.5   80.9  190.2
# 4       Adilabad  RAIN  1905.0   0.1   2.7   16.6   15.4   36.7  122.9  157.5
# ...          ...   ...     ...   ...   ...    ...    ...    ...    ...    ...
# 66153  Zunheboto  RAIN  2009.0   1.7  19.8   29.5   77.8  138.7  252.8  289.0
# 66154  Zunheboto  RAIN  2010.0   0.0   1.0  196.8  406.4  306.2  374.5  407.1
# 66155  Zunheboto  RAIN  2011.0  13.3  20.4   78.6  129.3  244.6  314.5  596.8
# 66156        NaN   avg  2003.0  18.8  22.3   28.0   44.6   74.3  186.4  314.6
# 66157        NaN   avg     NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN
#
# ...

# %%
#drop  var, WC14, WC16,WC17.W18
rainfall = rainfall.drop(['VAR', 'WC14', 'WC16', 'WC17', 'WC18'], axis=1)
rainfall
# Out:
#             DIST    Year   Jan   Feb    Mar    Apr    May    Jun    Jul  \
# 0       Adilabad  1901.0  14.8  74.1   19.3   64.2   11.7  159.1  337.9
# 1       Adilabad  1902.0   0.0   0.0    0.2    7.6   13.3   28.9  256.7
# 2       Adilabad  1903.0   5.0   7.7    0.0    2.5   15.4  103.5  516.4
# 3       Adilabad  1904.0   6.8   0.7   10.3    0.7   31.5   80.9  190.2
# 4       Adilabad  1905.0   0.1   2.7   16.6   15.4   36.7  122.9  157.5
# ...          ...     ...   ...   ...    ...    ...    ...    ...    ...
# 66153  Zunheboto  2009.0   1.7  19.8   29.5   77.8  138.7  252.8  289.0
# 66154  Zunheboto  2010.0   0.0   1.0  196.8  406.4  306.2  374.5  407.1
# 66155  Zunheboto  2011.0  13.3  20.4   78.6  129.3  244.6  314.5  596.8
# 66156        NaN  2003.0  18.8  22.3   28.0   44.6   74.3  186.4  314.6
# 66157        NaN     NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN
#
#          Aug    Sep    Oct   Nov   Dec    WC13    WC15
# ...

# %%
rainfall['DIST'].nunique()
# Out:
# 596

# %%
#drop last 2 rows
rainfall.drop(rainfall.tail(2).index,inplace=True)

# %%
rainfall
# Out:
#             DIST    Year   Jan   Feb    Mar    Apr    May    Jun    Jul  \
# 0       Adilabad  1901.0  14.8  74.1   19.3   64.2   11.7  159.1  337.9
# 1       Adilabad  1902.0   0.0   0.0    0.2    7.6   13.3   28.9  256.7
# 2       Adilabad  1903.0   5.0   7.7    0.0    2.5   15.4  103.5  516.4
# 3       Adilabad  1904.0   6.8   0.7   10.3    0.7   31.5   80.9  190.2
# 4       Adilabad  1905.0   0.1   2.7   16.6   15.4   36.7  122.9  157.5
# ...          ...     ...   ...   ...    ...    ...    ...    ...    ...
# 66151  Zunheboto  2007.0   2.4  30.8   20.2  203.7  193.3  283.6  373.1
# 66152  Zunheboto  2008.0  20.7  10.9   56.4  109.2  150.5  372.4  454.7
# 66153  Zunheboto  2009.0   1.7  19.8   29.5   77.8  138.7  252.8  289.0
# 66154  Zunheboto  2010.0   0.0   1.0  196.8  406.4  306.2  374.5  407.1
# 66155  Zunheboto  2011.0  13.3  20.4   78.6  129.3  244.6  314.5  596.8
#
#          Aug    Sep    Oct   Nov   Dec    WC13    WC15
# ...

# %%
#create a new column Summer Rainfall
rainfall['Summer'] = rainfall['Mar'] + rainfall['Apr'] + rainfall['May']+rainfall['Jun']

# %%
#create a new column Winter Rainfall and add dec of current year and jan and feb of next year
rainfall['Winter'] =rainfall['Dec'] +rainfall['Jan'].shift(-1) + rainfall['Feb'].shift(-1)

# %%
#create a new column Autumn and consider oct and nov
rainfall['Autumn'] = rainfall['Oct'] + rainfall['Nov']

# %%
#create a new column Rabi and consider oct, nov, dec
rainfall['Rabi'] = rainfall['Oct'] + rainfall['Nov'] + rainfall['Dec']

# %%
rainfall.head(10)
# Out:
#        DIST    Year   Jan   Feb   Mar   Apr   May    Jun    Jul    Aug    Sep  \
# 0  Adilabad  1901.0  14.8  74.1  19.3  64.2  11.7  159.1  337.9  298.0  154.5
# 1  Adilabad  1902.0   0.0   0.0   0.2   7.6  13.3   28.9  256.7  179.3  198.3
# 2  Adilabad  1903.0   5.0   7.7   0.0   2.5  15.4  103.5  516.4  379.9  196.5
# 3  Adilabad  1904.0   6.8   0.7  10.3   0.7  31.5   80.9  190.2  121.4  200.5
# 4  Adilabad  1905.0   0.1   2.7  16.6  15.4  36.7  122.9  157.5  281.8  297.8
# 5  Adilabad  1906.0  10.2   2.0  15.5   0.9   3.6  267.8  365.7  264.5  138.9
# 6  Adilabad  1907.0   5.1  12.7   7.2  76.6   0.2  152.5  294.9  373.4  128.5
# 7  Adilabad  1908.0  10.3  12.4   4.7   2.2   5.8  144.7  421.6  383.1  294.0
# 8  Adilabad  1909.0   4.9   6.3   2.1  32.2   1.9  127.8  437.0  184.3  125.8
# 9  Adilabad  1910.0   0.0   0.0   0.0   0.0  26.6  272.5  289.7  180.3  331.3
#
#      Oct   Nov   Dec    WC13    WC15  Summer  Winter  Autumn   Rabi
# ...

# %%
#rename column WC13 to annual
rainfall.rename(columns={'WC13':'Annual'}, inplace=True)
rainfall.rename(columns={'WC15':'Kharif'}, inplace=True)

# %%
#create a copy of rainfall
rainfall['Winter'].iloc[-1] = rainfall['Dec'].iloc[-1]
# Out:
# C:\Users\zatak\AppData\Local\Temp\ipykernel_13516\3490005134.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rainfall['Winter'].iloc[-1] = rainfall['Dec'].iloc[-1]

# %%
rainfall
# Out:
#             DIST    Year   Jan   Feb    Mar    Apr    May    Jun    Jul  \
# 0       Adilabad  1901.0  14.8  74.1   19.3   64.2   11.7  159.1  337.9
# 1       Adilabad  1902.0   0.0   0.0    0.2    7.6   13.3   28.9  256.7
# 2       Adilabad  1903.0   5.0   7.7    0.0    2.5   15.4  103.5  516.4
# 3       Adilabad  1904.0   6.8   0.7   10.3    0.7   31.5   80.9  190.2
# 4       Adilabad  1905.0   0.1   2.7   16.6   15.4   36.7  122.9  157.5
# ...          ...     ...   ...   ...    ...    ...    ...    ...    ...
# 66151  Zunheboto  2007.0   2.4  30.8   20.2  203.7  193.3  283.6  373.1
# 66152  Zunheboto  2008.0  20.7  10.9   56.4  109.2  150.5  372.4  454.7
# 66153  Zunheboto  2009.0   1.7  19.8   29.5   77.8  138.7  252.8  289.0
# 66154  Zunheboto  2010.0   0.0   1.0  196.8  406.4  306.2  374.5  407.1
# 66155  Zunheboto  2011.0  13.3  20.4   78.6  129.3  244.6  314.5  596.8
#
#          Aug    Sep    Oct   Nov   Dec  Annual  Kharif  Summer  Winter  \
# ...

# %%
rainfall.isnull().sum()
# Out:
# DIST      0
# Year      0
# Jan       0
# Feb       0
# Mar       0
# Apr       0
# May       0
# Jun       0
# Jul       0
# Aug       0
# Sep       0
# Oct       0
# Nov       0
# Dec       0
# Annual    0
# Kharif    0
# Summer    0
# Winter    0
# Autumn    0
# Rabi      0
# dtype: int64

# %%
#add +3 to year
rainfall['Year'] = rainfall['Year'] + 3

# %%
#export to csv
rainfall.to_csv('../Dataset Processed/Rainfall_cleaned.csv', index=False)
